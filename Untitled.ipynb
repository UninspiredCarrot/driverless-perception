# %%
from ultralytics import YOLO
from PIL import Image
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
model = YOLO('/Users/bolt/code/driverless-perception/runs/detect/train12/weights/best.pt')

# %%
left_image = '/Users/bolt/code/driverless-perception/zed-input-left.png'
right_image = '/Users/bolt/code/driverless-perception/zed-input-right.png'

# %%
cap = cv2.VideoCapture(0) # use 0 if you only have front facing camera
ret, frame = cap.read()
# Out:
# 2024-01-23 14:14:12.085 python[94170:14628803] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.

# %%
cap.read()
# Out:
# (True,
#  array([[[227, 255, 253],
#          [220, 255, 245],
#          [216, 249, 239],
#          ...,
#          [246, 251, 250],
#          [242, 245, 244],
#          [240, 243, 242]],
#
#         [[227, 255, 253],
#          [225, 255, 250],
#          [222, 255, 245],
#          ...,
#          [246, 251, 250],
#          [240, 245, 244],
#          [239, 244, 243]],
#
#         [[229, 255, 252],
#          [229, 255, 250],
#          [231, 255, 250],
#          ...,
#          [245, 253, 251],
#          [239, 247, 245],
#          [237, 245, 243]],
#
#         ...,
#
#         [[ 54,  84, 111],
#          [ 53,  83, 109],
#          [ 53,  83, 109],
#          ...,
#          [224, 227, 224],
#          [222, 226, 223],
#          [221, 225, 222]],
#
#         [[ 55,  82, 109],
#          [ 55,  82, 109],
#          [ 54,  81, 108],
#          ...,
#          [217, 220, 217],
#          [217, 220, 217],
#          [215, 219, 216]],
#
#         [[ 54,  81, 108],
#          [ 54,  81, 108],
#          [ 54,  81, 108],
#          ...,
#          [217, 220, 217],
#          [217, 220, 217],
#          [215, 219, 216]]], dtype=uint8))

# %%
image = frame #note: image needs to be in the opencv format
height, width, channels = image.shape
right_image = image[0:height, int(width/2):width] #this line crops
left_image = image[0:height, 0:int(width/2)] #this line crops

# %%
cap.get(cv2.CAP_PROP_FRAME_WIDTH)
# Out:
# 2560.0

# %%
cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
# Out:
# 720.0

# %%
# Display the image with the bounding box using matplotlib
plt.imshow(left_image)
plt.show()

# %%
# Display the image with the bounding box using matplotlib
plt.imshow(right_image)
plt.show()

# %%
def template_matching(left_image, right_image, pl_x, pl_y, window_size):
    template = left_image[pl_y - window_size//2:pl_y + window_size//2, pl_x - window_size//2:pl_x + window_size//2]

    min_similarity = float('inf')

    pr_x = 0

    lower_lim = pl_x - 200
    if lower_lim < 0:
        lower_lim = 0
    upper_lim = pl_x + 200
    if upper_lim > right_image.shape[1]:
        upper_lim = right_image.shape[1]

    for x in range(lower_lim, upper_lim):
        window = right_image[pl_y - window_size//2:pl_y + window_size//2, x - window_size//2:x + window_size//2]

        similarity = np.sum((template - window)**2)

        if similarity < min_similarity:
            min_similarity = similarity
            pr_x = x

    pr_y = pl_y

    return pr_x, pr_y

# %%
results = model(left_image)

x,y,w,h = results[0].boxes.xywh[0]

image = left_image

x = x.item()
y = y.item()
w = w.item()
h = h.item()

x, y, w, h = int(x), int(y), int(w), int(h)

# Draw the bounding box on the image
color = (255, 255, 0)  # Green color (BGR format)
thickness = 2  # Line thickness

# Calculate the coordinates of the opposite corners of the bounding box
start_point = (x, y)
end_point = (x + w, y + h)

# Draw the bounding box rectangle on the image
cv2.rectangle(image, start_point, end_point, color, thickness)

# Convert BGR image to RGB for displaying with matplotlib
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image with the bounding box using matplotlib
plt.imshow(image_rgb)
plt.title("Image with Bounding Box")
plt.axis("off")
plt.show()
plt.close()
# Out:
# 0: 384x640 1 yellow_cone, 1 blue_cone, 76.9ms
# Speed: 4.1ms preprocess, 76.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)

# %%
results = model(right_image)

for result in results[0].boxes.xywh

x2,y2,w2,h2 = results[0].boxes.xywh[1]

image = right_image

x2 = x2.item()
y2 = y2.item()
w2 = w2.item()
h2 = h2.item()

x2, y2, w2, h2 = int(x2), int(y2), int(w2), int(h2)

# Draw the bounding box on the image
color = (0, 255, 0)  # Green color (BGR format)
thickness = 2  # Line thickness

# Calculate the coordinates of the opposite corners of the bounding box
start_point = (x2, y2)
end_point = (x2 + w2, y2 + h2)

# Draw the bounding box rectangle on the image
cv2.rectangle(image, start_point, end_point, color, thickness)

# Convert BGR image to RGB for displaying with matplotlib
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image with the bounding box using matplotlib
plt.imshow(image_rgb)
plt.title("Image with Bounding Box")
plt.axis("off")
plt.show()
plt.close()
# Out:
# 0: 384x640 3 yellow_cones, 1 blue_cone, 69.9ms
# Speed: 9.2ms preprocess, 69.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)

# %%
x2, y2 = template_matching(left_image = np.array(left_image), right_image = np.array(right_image), pl_x = x, pl_y = y, window_size = h)
disparity = x - x2
focal_length = 528
pixel_size = 0.004
baseline = 120
depth = (focal_length/pixel_size) * (baseline/np.abs(disparity))
print(depth/100)
# Out:
# 960.0

# %%
results[0].boxes.cls
# Out:
# tensor([1., 0.])

# %%
x, y, x2, y2
# Out:
# (654, 484, 504, 484)

# %%
image_path = '/Users/bolt/code/driverless-perception/zed-input-right.png'
image = right_image

# Calculate the coordinates of the opposite corners of the bounding box
start_point = (x, y)
end_point = (x + w, y + h)

# Draw the bounding box rectangle on the image
cv2.rectangle(image, start_point, end_point, color, thickness)

# Convert BGR image to RGB for displaying with matplotlib
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image with the bounding box using matplotlib
plt.imshow(image_rgb)
plt.title("Image with Bounding Box")
plt.axis("off")
plt.show()

# %%
w
# Out:
# 36

# %%
# Out:
# (648, 704, 28, 704)

# %%
disparity
# Out:
# 15

# %%
x2, y2 = template_matching(left_image = np.array(cv2.imread(left_image)), right_image = np.array(cv2.imread(right_image)), pl_x = x, pl_y = y, window_size = 20)
disparity = x - x2
focal_length = 1066
pixel_size = 0.002
baseline = 120
depth = (focal_length/pixel_size) * (baseline/disparity)
depth/1000
# Out:
# 1305.3061224489797

# %%
depth = (focal_length/pixel_size) * (baseline/disparity)

# %%
hi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 hi
#
# NameError: name 'hi' is not defined
